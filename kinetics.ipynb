# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from scipy.optimize import curve_fit

# %%
from math import exp

# %%
import numpy as np

# %% [markdown]
# # Preprocessing

# %%
df = pd.read_csv("E:/2019-0838/0838_001/0838_001_exercise.txt", sep='\t')

# %%
df = df.filter(['TCD1'])

# %%
tcd1= df.filter(['TCD1'])

time1=3
timearray=[]
for i in tcd1.iterrows():
    timearray.append(time1)
    time1+=3
tcd1['Time']=timearray
print(tcd1)
# Out:
#           TCD1  Time
# 0    87.017702     3
# 1    72.153646     6
# 2    60.707113     9
# 3    70.962758    12
# 4    89.987794    15
# ..         ...   ...
# 212  77.696853   639
# 213  78.068880   642
# 214  70.735210   645
# 215  75.579773   648
# 216  82.088148   651
#
# [217 rows x 2 columns]

# %%
df = df.drop([df.index[0], df.index[1]])

# %%
# todo: add time column that starts at 3 increments 3 to end

# %%
df['TCD1'] = df['TCD1'].astype(float)

# %%
df = df.reset_index()

# %%
df.drop(['index'], axis=1, inplace=True
# Out:
#   File "<ipython-input-18-aac2339e8d62>", line 1
#     df.drop(['index'], axis=1, inplace=True
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
plt.plot(df['TCD1'])

# %% [markdown]
# # Curve Fitting

# %%
def func(y0, amp, TD, tau, t):
    return y0 + amp * (1 - exp((-t-TD)/tau))

# %%
xdata = df.index.values
ydata = df['TCD1']

# %%
popt, pcov = curve_fit(func, xdata, ydata)

# %%
y0 = popt[0]
amp = popt[1]
TD = popt[2]
tau = popt[3]
t= tcd1['Time']

# %%
def func(y0, amp, TD, tau, t):
    return np.int(x)
f2 = np.vectorize(func)
x = np.arange(y0, amp, TD, tau, t)
plt.plot(x, f2(x))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-35552fcf91ff> in <module>
#       2     return np.int(x)
#       3 f2 = np.vectorize(func)
# ----> 4 x = np.arange(y0, amp, TD, tau, t)
#       5 plt.plot(x, f2(x))
#       6 plt.show()
#
# TypeError: arange() takes at most 4 positional arguments (5 given)

# %%
def func(y0, amp, TD, tau, t):
    return y0 + amp * (1 - exp((-t-TD)/tau))
    return np.int(x)
a = np.vectorize(y0)
b = np.vectorize(amp)
c = np.vectorize(TD)
d = np.vectorize(tau)
e = np.vectorize(t)

# %%
t= t*-1
def func(y0, amp, TD, tau, t):
    return y0 + amp * (1 - exp((t-TD)/tau))
    return np.int(x)
x = np.array((range(200))
y= func(y0, amp, TD, tau, t)
plt.plot(x,y, label='y = y0 + amp * (1 - exp((-t-TD)/tau))')
# Out:
#   File "<ipython-input-28-785c020c241a>", line 6
#     y= func(y0, amp, TD, tau, t)
#     ^
# SyntaxError: invalid syntax

# %%
# todo: fix error: only size-1 arrays can be converted to Python scalars
# todo: plot data and curve

# %%
plt.plot(df['TCD1'], 'b-')
plt.plot(xdata, func(y0, amp, TD, tau, xdata), 'r-')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TCD1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-69d26ec77027> in <module>
# ...
